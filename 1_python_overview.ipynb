# %% [markdown]
# # Overview of Python Visualization Toolkit
#
# These two talks provide pretty good overview of the Python visualization landscape.
#
# - Jake VanderPlas at PyCon 2017: [The Python Visualization Landscape](https://www.youtube.com/watch?v=FytuB8nFHPQ).
# - James Bednar at AnacondaCon 2018: [PyViz: Dashboards for Visualizing 1 Billion Datapoints in 30 Lines of Python](https://www.youtube.com/watch?v=k27MJJLJNT4).

# %% [markdown]
# # Python environment setup instruction
#
# When you work on data visualizations, there are two main choices: local and cloud. Working locally means installing various packages in your computer and working on the cloud means using services like Google Colaboratory.
#
# Local installation can be nice and convenient (when it works) because everything is in your computer. You can work without network connection and everything can be configured exactly as you see fit. However, local installation can be a huge source of pain because there are multiple ways to install packages (e.g., Anaconda, System Python, etc.) and they can interfere and break. This "dependency hell" can be extremely frustrating. At the same time, working locally is limited by the power of your computer. For instance, you may not be able to run a heavy computational task because your laptop is 10 years old or because you refuse to delete a game for a huge dataset.
#
# On the other hand, working on a cloud environment can also be nice and convenient (when it works). You don't need to worry about different installation and dependency hell, as long as the environment that the cloud provider provides is adequate. All computation is done on the cloud so your computer will not suffer. But that also means you can only work within the boundary set by the cloud provider. For instance the free Google Colaboratory has a certain limit on memory and disk usage, and to go beyond you have to pay.
#
# My recommendation is the following: if you are comfortable with managing your computer and multiple Python installations and packages, or want to learn system management, go with local option. You can either use Anaconda or just vanilla Python (with `virtuanenv` and `pip`). If you don't want to spend time on this, use Google Colaboratory.
#
# ## Local setup
#
# If you don't have much experience with Python ecosystem, we recommend using Anaconda, which makes most data analysis tasks easier. But it is totally fine not to use Anaconda.
#
#
# ### Setting up Anaconda environment
#
# Anaconda is a popular, all-in-one Python package distribution system. If your work is focused on data analysis, machine learning, visualization, etc., then just sticking with Anaconda is probably the most convenient way to manage multiple Python versions, packages, and virtual environments. Anaconda comes with a package manager called `conda` that replaces `pip` and `virtualenv`. It allows you to install packages, create virtual environments, and more. It even allows you to set a different Python version for each virtual environment. If you use Anaconda, you want to stick to it as much as possible by exclusively using `conda` (use `pip` only when there is no way to install with `conda`).
#
# First, download Anaconda for your system from [here](https://www.anaconda.com/download). Follow the instructions and reopen your shell (or use the Anaconda GUI system). By default, Anaconda activates `base` environment. You can install packages by running
#
# ```
# $ conda install packagename
# ```
#
# Let's install core Python data packages.
#
# ```
# $ conda install numpy scipy pandas scikit-learn matplotlib seaborn jupyter jupyterlab
# ```
#
# We usually want to use a virtual environment for each of your project. By using virtual environments, you can isolate each environment from the others and maintain separate sets (versions) of packages. `conda` has a built-in support for virtual environments.
#
# ```
# $ conda create -n dviz python=3.8
# ```
#
# This command creates a virtual environment named (`-n`) `dviz` with Python 3.8. You can activate the environment (whenever you begins to work on this course) by running
#
# ```
# $ conda activate dviz
# ```
#
# and deactivate (when you're done) by running
#
# ```
# $ conda deactivate
# ```
#
# For the full documentation, see https://conda.io/docs/user-guide/tasks/manage-environments.html
#
# When the environment is activated, your prompt will show the name of the environment. Now if you install a package, it will be installed into this environment, but not in the other virtual environment. In other words, each virtual environment maintains its own "world" and totally different packages can be installed in each "world".
#
# But even if you have created a virtual environment and installed all necessary packages, you can't use this environment in the Jupyter notebook/Lab yet. Jupyter needs a special program called "IPython kernel" to execute code. So, for each virtual environment we need to also create a corresponding kernel. We can do manually by using `ipykernel` package like following:
#
# ```
# $ conda activate dviz
# $ conda install ipykernel
# $ python -m ipykernel install --user --name=dviz
# ```
#
# or we can use [`nb_conda`](https://github.com/Anaconda-Platform/nb_conda) package by installing it.
#
# ```
# $ conda install nb_conda
# ```
#
# Once it's installed, kernels for all virtual environments created by `conda` are automatically created and show up in Jupyter. So this is a much more convenient option.
#
#
# ### `pip` + `virtualenv`
#
# If you are not using Anaconda, you can use Python's `virtualenv` to create virtual environments and `pip` to install packages to the virtual environments. See https://docs.python.org/3/tutorial/venv.html For instance, you can run the following to create a virtual environment in the current directory (it will create `dviz-env` folder).
#
# ```
# $ python3 -m venv dviz-env
# ```
#
# and then activate and deactivate it by
#
# ```
# $ source dviz-env/bin/activate
# $ deactivate
# ```
#
# Once you activate a virtual environment, you can install packages into it with `pip`.
#
# ```
# $ pip install packagename
# ```
#
# Like the case with `conda`, we need to install a kernel for each virtual environment to use it in Jupyter.
#
# ```
# $ source dviz-env/bin/activate
# $ pip install ipykernel
# $ python -m ipykernel install --user --name=dviz
# ```
#
# ### Jupyter
#
# Once you have setup your local environment, you can run
#
# ```
# $ jupyter lab
# ```
#
# or use Jupyter notebook.
#
# ```
# jupyter notebook
# ```
#
# Jupyter lab is the 'next generation' notebook system with many powerful features. Some packages that we use work more nicely with Jupyter lab (for some lab assignments you may need to use jupyter notebook instead of the lab).
#
# Jupyter also has a desktop app: https://github.com/jupyterlab/jupyterlab-desktop
#
# ### nteract
#
# Another convenient way to use Jupyter is using the [`nteract` app](https://nteract.io). This is essentially a desktop Jupyter app. Instead of running Jupyter server and using a web browser, you can simply open a notebook file with `nteract` app and you'll be able to run the code as if you're using the Jupyter on the web. If you use Atom editor, you can make it interactive by using https://nteract.io/atom.
#
# ### VS code
#
# [Visual Studio code](https://code.visualstudio.com/) is a powerful editor and it supports notebooks and interactivity for Python. If you open a Jupyter notebook file, it works seamlessly within VS code. With the [Remote - SSH plugin](https://marketplace.visualstudio.com/items?itemName=ms-vscode-remote.remote-ssh), you can maintain almost identical experience using a computing server.
#
#
# ## Cloud setup
#
# There are many cloud-based Jupyter notebook services. The best option is probably the Google Colaboratory. It allows installation of packages and you can even use GPU/TPUs!
#
# ### Google colaboratory
#
# [Google Colaboratory](https://colab.research.google.com/) is Google's collaborative Jupyter notebook service. This is the recommended cloud option. Most packages that we use are already installed and you can install additioanl packages by running
#
# ```
# !pip install packagename
# ```
#
# in the computing cell.
#
#
# ### Other options
#
# - Azure notebooks: Microsoft also has a cloud notebook service called [Azure notebooks](https://notebooks.azure.com/). This service also allows installing new packages through `!pip install ...`.
# - CoCalc (https://cocalc.com/) is a service by [SageMath](http://www.sagemath.org/). You can use it freely but the free version is slow and can be turned off without warning. Most of the packages that we use are pre-installed. We may be able to provide a subscription through the school.
# - Kaggle Kernels: The famous machine learning / data science competition service Kaggle offers cloud-based notebooks called [Kaggle kernels](https://www.kaggle.com/kernels). Because you can directly use all the Kaggle datasets, it is an excellent option to do your project if you use one of the Kaggle datasets. It allows uploading your own dataset and install some packages, but not all packages are supported.
#
#
#
# # Lab assignment
#
# 1. Set up your local Python environment following the instructions. You should be using a virtual environment on your local machine.
# 1. Install Jupyter notebook and Jupyter lab.
# 1. Launch jupyter notebook (lab)
# 1. Create a new notebook and play with it. Print "Hello world!".
#
# If you want to use a cloud environment,
#
# 1. Try out the cloud environments listed above. (Google colaboratory is recommended)
# 1. Try installing/importing the following packages.
# 1. Create a cell that prints "Hello world!".
# 1. Submit the notebook.
#
#
# Finally, these are the packages that we plan to use. So check out their homepages and figure out what they are about.
#
# - Jupyter Notebook and Lab: https://jupyter.org/
# - numpy: http://www.numpy.org/
# - scipy: http://www.scipy.org/
# - matplotlib: http://matplotlib.org/
# - seaborn: http://seaborn.pydata.org/
# - pandas: http://pandas.pydata.org/
# - scikit-learn: http://scikit-learn.org/stable/
# - altair: https://github.com/altair-viz/altair
# - vega_datasets: https://github.com/altair-viz/vega_datasets
# - bokeh: http://bokeh.pydata.org/en/latest/
# - datashader: http://datashader.org/
# - holoviews: http://holoviews.org/
# - wordcloud: https://github.com/amueller/word_cloud
# - spacy: https://spacy.io/
#
# Install them using your package manager (conda or pip).
#
# Once you have installed the Jupyter locally or succeeded with a cloud environment, run the following import cell to make sure that every package is installed successfully. Submit the notebook on the canvas.

# %%
# !pip install numpy scipy matplotlib seaborn pandas altair vega_datasets sklearn bokeh datashader holoviews wordcloud spacy
# Out:
# Requirement already satisfied: numpy in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (1.23.5)
# Requirement already satisfied: scipy in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (1.10.0)
# Requirement already satisfied: matplotlib in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (3.7.0)
# Requirement already satisfied: seaborn in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: pandas in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: altair in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (5.0.1)
# Requirement already satisfied: vega_datasets in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: sklearn in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (0.0.post5)
# Requirement already satisfied: bokeh in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (2.4.3)
# Requirement already satisfied: datashader in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (0.14.4)
# Requirement already satisfied: holoviews in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (1.15.4)
# Requirement already satisfied: wordcloud in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (1.9.2)
# Requirement already satisfied: spacy in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (3.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: cycler>=0.10 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: jinja2 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from altair) (3.1.2)
# Requirement already satisfied: toolz in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from altair) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from altair) (4.17.3)
# Requirement already satisfied: typing-extensions>=4.0.1 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from altair) (4.4.0)
# Requirement already satisfied: tornado>=5.1 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from bokeh) (6.1)
# Requirement already satisfied: PyYAML>=3.10 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from bokeh) (6.0)
# Requirement already satisfied: requests in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from datashader) (2.28.1)
# Requirement already satisfied: dask in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from datashader) (2022.7.0)
# Requirement already satisfied: datashape in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from datashader) (0.5.4)
# Requirement already satisfied: xarray in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from datashader) (2022.11.0)
# Requirement already satisfied: pyct in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from datashader) (0.5.0)
# Requirement already satisfied: param in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from datashader) (1.12.3)
# Requirement already satisfied: colorcet in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from datashader) (3.0.1)
# Requirement already satisfied: numba>=0.51 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from datashader) (0.56.4)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from holoviews) (2.0.2)
# Requirement already satisfied: panel>=0.13.1 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from holoviews) (0.14.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: pathy>=0.10.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (1.1.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (8.1.10)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (2.4.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (4.64.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (1.10.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: setuptools in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from spacy) (65.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from jinja2->altair) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair) (22.1.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from numba>=0.51->datashader) (0.39.1)
# Requirement already satisfied: markdown in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from panel>=0.13.1->holoviews) (3.4.1)
# Requirement already satisfied: bleach in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from panel>=0.13.1->holoviews) (4.1.0)
# Requirement already satisfied: six>=1.5 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from requests->datashader) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from requests->datashader) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from requests->datashader) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from requests->datashader) (1.26.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpickle>=1.1.1 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from dask->datashader) (2.0.0)
# Requirement already satisfied: partd>=0.3.10 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from dask->datashader) (1.2.0)
# Requirement already satisfied: fsspec>=0.6.0 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from dask->datashader) (2022.11.0)
# Requirement already satisfied: multipledispatch>=0.4.7 in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from datashape->datashader) (0.6.0)
# Requirement already satisfied: locket in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from partd>=0.3.10->dask->datashader) (1.0.0)
# Requirement already satisfied: webencodings in /Users/doyinadeniyi/anaconda3/lib/python3.10/site-packages (from bleach->panel>=0.13.1->holoviews) (0.5.1)

# %%
import numpy
import scipy
import matplotlib
import seaborn
import pandas
import altair
import vega_datasets
import sklearn
import bokeh
import datashader
import holoviews
import wordcloud
import spacy

# %%
conda install -c conda-forge prophet
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/doyinadeniyi/anaconda3
#
#   added / updated specs:
#     - prophet
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.5.7   |       hf0a4a13_0         145 KB  conda-forge
#     certifi-2023.5.7           |     pyhd8ed1ab_0         149 KB  conda-forge
#     clang-14.0.6               |       hca03da5_1         138 KB
#     clang-14-14.0.6            |default_h1b80db6_1         1.1 MB
#     clang_osx-arm64-14.0.6     |       h15773ab_6          20 KB  conda-forge
#     clangxx-14.0.6             |default_h1b80db6_1         138 KB
#     clangxx_osx-arm64-14.0.6   |       he29aa18_6          19 KB  conda-forge
#     cmdstan-2.31.0             |       h5143e03_0        43.7 MB
#     cmdstanpy-1.1.0            |     pyhd8ed1ab_0          64 KB  conda-forge
#     compiler-rt-14.0.6         |       h4ccfd99_0          87 KB
#     compiler-rt_osx-arm64-14.0.6|       h4fb70ea_0         3.2 MB
#     convertdate-2.4.0          |     pyhd8ed1ab_0          38 KB  conda-forge
#     ephem-4.1.2                |  py310h1a28f6b_0         1.3 MB
#     holidays-0.26              |     pyhd8ed1ab_0         218 KB  conda-forge
#     importlib_resources-5.12.0 |     pyhd8ed1ab_0          30 KB  conda-forge
#     libclang-cpp14-14.0.6      |default_h1b80db6_1        11.8 MB
#     llvm-tools-14.0.6          |       hfd8c8a6_2        10.4 MB
#     lunarcalendar-0.0.9        |             py_0          20 KB  conda-forge
#     make-4.3                   |       he57ea6c_1         247 KB  conda-forge
#     openssl-1.1.1u             |       h53f4e23_0         1.6 MB  conda-forge
#     prophet-1.1.3              |  py310hb6aeb05_0         636 KB
#     pymeeus-0.5.12             |     pyhd8ed1ab_0         507 KB  conda-forge
#     tbb-2021.9.0               |       hffc8910_0         119 KB  conda-forge
#     tbb-devel-2021.9.0         |       h4f9cb39_0         999 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        76.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   clang              pkgs/main/osx-arm64::clang-14.0.6-hca03da5_1
#   clang-14           pkgs/main/osx-arm64::clang-14-14.0.6-default_h1b80db6_1
#   clang_osx-arm64    conda-forge/osx-arm64::clang_osx-arm64-14.0.6-h15773ab_6
#   clangxx            pkgs/main/osx-arm64::clangxx-14.0.6-default_h1b80db6_1
#   clangxx_osx-arm64  conda-forge/osx-arm64::clangxx_osx-arm64-14.0.6-he29aa18_6
#   cmdstan            pkgs/main/osx-arm64::cmdstan-2.31.0-h5143e03_0
#   cmdstanpy          conda-forge/noarch::cmdstanpy-1.1.0-pyhd8ed1ab_0
#   compiler-rt        pkgs/main/osx-arm64::compiler-rt-14.0.6-h4ccfd99_0
#   compiler-rt_osx-a~ pkgs/main/osx-arm64::compiler-rt_osx-arm64-14.0.6-h4fb70ea_0
#   convertdate        conda-forge/noarch::convertdate-2.4.0-pyhd8ed1ab_0
#   ephem              pkgs/main/osx-arm64::ephem-4.1.2-py310h1a28f6b_0
#   holidays           conda-forge/noarch::holidays-0.26-pyhd8ed1ab_0
#   importlib_resourc~ conda-forge/noarch::importlib_resources-5.12.0-pyhd8ed1ab_0
#   libclang-cpp14     pkgs/main/osx-arm64::libclang-cpp14-14.0.6-default_h1b80db6_1
#   llvm-tools         pkgs/main/osx-arm64::llvm-tools-14.0.6-hfd8c8a6_2
#   lunarcalendar      conda-forge/noarch::lunarcalendar-0.0.9-py_0
#   make               conda-forge/osx-arm64::make-4.3-he57ea6c_1
#   prophet            pkgs/main/osx-arm64::prophet-1.1.3-py310hb6aeb05_0
#   pymeeus            conda-forge/noarch::pymeeus-0.5.12-pyhd8ed1ab_0
#   tbb-devel          conda-forge/osx-arm64::tbb-devel-2021.9.0-h4f9cb39_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2023.5.7-hf0a4a13_0
#   certifi            pkgs/main/osx-arm64::certifi-2022.12.~ --> conda-forge/noarch::certifi-2023.5.7-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-1.1.1t-h1a28f6b_0 --> conda-forge::openssl-1.1.1u-h53f4e23_0
#   tbb                    pkgs/main::tbb-2021.7.0-h48ca7d4_0 --> conda-forge::tbb-2021.9.0-hffc8910_0
#
#
#
# Downloading and Extracting Packages
# prophet-1.1.3        | 636 KB    |                                       |   0%
# certifi-2023.5.7     | 149 KB    |                                       |   0%
#
# compiler-rt_osx-arm6 | 3.2 MB    |                                       |   0%
#
#
# tbb-2021.9.0         | 119 KB    |                                       |   0%
#
#
#
# ephem-4.1.2          | 1.3 MB    |                                       |   0%
#
#
#
#
# ca-certificates-2023 | 145 KB    |                                       |   0%
#
#
#
#
#
# clang_osx-arm64-14.0 | 20 KB     |                                       |   0%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   |                                       |   0%
#
#
#
#
#
#
#
# make-4.3             | 247 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# pymeeus-0.5.12       | 507 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# tbb-devel-2021.9.0   | 999 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# clang-14-14.0.6      | 1.1 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp14-14.0. | 11.8 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# clang-14.0.6         | 138 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cmdstanpy-1.1.0      | 64 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# compiler-rt-14.0.6   | 87 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lunarcalendar-0.0.9  | 20 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# convertdate-2.4.0    | 38 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx_osx-arm64-14 | 19 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1u       | 1.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 30 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx-14.0.6       | 138 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# holidays-0.26        | 218 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# certifi-2023.5.7     | 149 KB    | ##################################### | 100%
#
#
#
#
# ca-certificates-2023 | 145 KB    | ####                                  |  11%
#
#
#
#
# ca-certificates-2023 | 145 KB    | ##################################### | 100%
#
#
#
# ephem-4.1.2          | 1.3 MB    | 4                                     |   1%
#
#
# tbb-2021.9.0         | 119 KB    | ####9                                 |  13%
#
# prophet-1.1.3        | 636 KB    | 9                                     |   3%
#
#
# tbb-2021.9.0         | 119 KB    | ##################################### | 100%
#
#
#
# ephem-4.1.2          | 1.3 MB    | ###########################9          |  76%
#
#
#
#
#
# clang_osx-arm64-14.0 | 20 KB     | #############################5        |  80%
#
# compiler-rt_osx-arm6 | 3.2 MB    | #                                     |   3%
#
#
#
#
#
# prophet-1.1.3        | 636 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# pymeeus-0.5.12       | 507 KB    | #1                                    |   3%
#
#
#
# ephem-4.1.2          | 1.3 MB    | ##################################### | 100%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   |                                       |   0%
#
#
#
#
#
#
#
#
# pymeeus-0.5.12       | 507 KB    | ##################################### | 100%
#
# compiler-rt_osx-arm6 | 3.2 MB    | ####7                                 |  13%
#
#
#
#
#
#
#
# make-4.3             | 247 KB    | ##3                                   |   6%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | 4                                     |   1%
#
#
#
#
#
#
#
#
#
# tbb-devel-2021.9.0   | 999 KB    | 5                                     |   2%
#
# compiler-rt_osx-arm6 | 3.2 MB    | ############7                         |  34%
#
#
#
#
#
#
#
# make-4.3             | 247 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# clang-14-14.0.6      | 1.1 MB    | 5                                     |   1%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | 9                                     |   2%
#
#
#
#
#
#
#
#
#
# tbb-devel-2021.9.0   | 999 KB    | #############################6        |  80%
#
# compiler-rt_osx-arm6 | 3.2 MB    | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp14-14.0. | 11.8 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# clang-14-14.0.6      | 1.1 MB    | ###############6                      |  42%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | #8                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp14-14.0. | 11.8 MB   | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
#
# clang-14.0.6         | 138 KB    | ####2                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cmdstanpy-1.1.0      | 64 KB     | #########2                            |  25%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lunarcalendar-0.0.9  | 20 KB     | ##############################2       |  82%
#
# compiler-rt_osx-arm6 | 3.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# convertdate-2.4.0    | 38 KB     | ###############5                      |  42%
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp14-14.0. | 11.8 MB   | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
# clang-14.0.6         | 138 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cmdstanpy-1.1.0      | 64 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cmdstanpy-1.1.0      | 64 KB     | ##################################### | 100%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | #####7                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lunarcalendar-0.0.9  | 20 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# compiler-rt-14.0.6   | 87 KB     | ######7                               |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1u       | 1.6 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# convertdate-2.4.0    | 38 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# tbb-devel-2021.9.0   | 999 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# compiler-rt-14.0.6   | 87 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# clang-14-14.0.6      | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# clang-14-14.0.6      | 1.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp14-14.0. | 11.8 MB   | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 30 KB     | ###################5                  |  53%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | #######2                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1u       | 1.6 MB    | ######9                               |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx_osx-arm64-14 | 19 KB     | ###############################2      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx_osx-arm64-14 | 19 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp14-14.0. | 11.8 MB   | #################                     |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# holidays-0.26        | 218 KB    | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1u       | 1.6 MB    | ################8                     |  46%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ########6                             |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx-14.0.6       | 138 KB    | ####2                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp14-14.0. | 11.8 MB   | #######################2              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx-14.0.6       | 138 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# holidays-0.26        | 218 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# holidays-0.26        | 218 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1u       | 1.6 MB    | #######################4              |  63%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | #########9                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp14-14.0. | 11.8 MB   | ###########################6          |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1u       | 1.6 MB    | ##############################        |  81%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ###########1                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp14-14.0. | 11.8 MB   | ###############################7      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1u       | 1.6 MB    | ####################################6 |  99%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ############4                         |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1u       | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp14-14.0. | 11.8 MB   | ###################################5  |  96%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | #############6                        |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp14-14.0. | 11.8 MB   | ##################################### | 100%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ################5                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | #################9                    |  48%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ###################2                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ####################7                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ######################1               |  60%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | #######################5              |  64%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | #########################3            |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ###########################6          |  75%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ##############################3       |  82%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ################################7     |  88%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ####################################3 |  98%
#
#
#
#
#
#
# cmdstan-2.31.0       | 43.7 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
