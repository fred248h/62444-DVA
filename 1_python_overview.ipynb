# %% [markdown]
# # Overview of Python Visualization Toolkit
#
# These two talks provide pretty good overview of the Python visualization landscape.
#
# - Jake VanderPlas at PyCon 2017: [The Python Visualization Landscape](https://www.youtube.com/watch?v=FytuB8nFHPQ).
# - James Bednar at AnacondaCon 2018: [PyViz: Dashboards for Visualizing 1 Billion Datapoints in 30 Lines of Python](https://www.youtube.com/watch?v=k27MJJLJNT4).

# %% [markdown]
# # Python environment setup instruction
#
# When you work on data visualizations, there are two main choices: local and cloud. Working locally means installing various packages in your computer and working on the cloud means using services like Google Colaboratory.
#
# Local installation can be nice and convenient (when it works) because everything is in your computer. You can work without network connection and everything can be configured exactly as you see fit. However, local installation can be a huge source of pain because there are multiple ways to install packages (e.g., Anaconda, System Python, etc.) and they can interfere and break. This "dependency hell" can be extremely frustrating. At the same time, working locally is limited by the power of your computer. For instance, you may not be able to run a heavy computational task because your laptop is 10 years old or because you refuse to delete a game for a huge dataset.
#
# On the other hand, working on a cloud environment can also be nice and convenient (when it works). You don't need to worry about different installation and dependency hell, as long as the environment that the cloud provider provides is adequate. All computation is done on the cloud so your computer will not suffer. But that also means you can only work within the boundary set by the cloud provider. For instance the free Google Colaboratory has a certain limit on memory and disk usage, and to go beyond you have to pay.
#
# My recommendation is the following: if you are comfortable with managing your computer and multiple Python installations and packages, or want to learn system management, go with local option. You can either use Anaconda or just vanilla Python (with `virtuanenv` and `pip`). If you don't want to spend time on this, use Google Colaboratory.
#
# ## Local setup
#
# If you don't have much experience with Python ecosystem, we recommend using Anaconda, which makes most data analysis tasks easier. But it is totally fine not to use Anaconda.
#
#
# ### Setting up Anaconda environment
#
# Anaconda is a popular, all-in-one Python package distribution system. If your work is focused on data analysis, machine learning, visualization, etc., then just sticking with Anaconda is probably the most convenient way to manage multiple Python versions, packages, and virtual environments. Anaconda comes with a package manager called `conda` that replaces `pip` and `virtualenv`. It allows you to install packages, create virtual environments, and more. It even allows you to set a different Python version for each virtual environment. If you use Anaconda, you want to stick to it as much as possible by exclusively using `conda` (use `pip` only when there is no way to install with `conda`).
#
# First, download Anaconda for your system from [here](https://www.anaconda.com/download). Follow the instructions and reopen your shell (or use the Anaconda GUI system). By default, Anaconda activates `base` environment. You can install packages by running
#
# ```
# $ conda install packagename
# ```
#
# Let's install core Python data packages.
#
# ```
# $ conda install numpy scipy pandas scikit-learn matplotlib seaborn jupyter jupyterlab
# ```
#
# We usually want to use a virtual environment for each of your project. By using virtual environments, you can isolate each environment from the others and maintain separate sets (versions) of packages. `conda` has a built-in support for virtual environments.
#
# ```
# $ conda create -n dviz python=3.8
# ```
#
# This command creates a virtual environment named (`-n`) `dviz` with Python 3.8. You can activate the environment (whenever you begins to work on this course) by running
#
# ```
# $ conda activate dviz
# ```
#
# and deactivate (when you're done) by running
#
# ```
# $ conda deactivate
# ```
#
# For the full documentation, see https://conda.io/docs/user-guide/tasks/manage-environments.html
#
# When the environment is activated, your prompt will show the name of the environment. Now if you install a package, it will be installed into this environment, but not in the other virtual environment. In other words, each virtual environment maintains its own "world" and totally different packages can be installed in each "world".
#
# But even if you have created a virtual environment and installed all necessary packages, you can't use this environment in the Jupyter notebook/Lab yet. Jupyter needs a special program called "IPython kernel" to execute code. So, for each virtual environment we need to also create a corresponding kernel. We can do manually by using `ipykernel` package like following:
#
# ```
# $ conda activate dviz
# $ conda install ipykernel
# $ python -m ipykernel install --user --name=dviz
# ```
#
# or we can use [`nb_conda`](https://github.com/Anaconda-Platform/nb_conda) package by installing it.
#
# ```
# $ conda install nb_conda
# ```
#
# Once it's installed, kernels for all virtual environments created by `conda` are automatically created and show up in Jupyter. So this is a much more convenient option.
#
#
# ### `pip` + `virtualenv`
#
# If you are not using Anaconda, you can use Python's `virtualenv` to create virtual environments and `pip` to install packages to the virtual environments. See https://docs.python.org/3/tutorial/venv.html For instance, you can run the following to create a virtual environment in the current directory (it will create `dviz-env` folder).
#
# ```
# $ python3 -m venv dviz-env
# ```
#
# and then activate and deactivate it by
#
# ```
# $ source dviz-env/bin/activate
# $ deactivate
# ```
#
# Once you activate a virtual environment, you can install packages into it with `pip`.
#
# ```
# $ pip install packagename
# ```
#
# Like the case with `conda`, we need to install a kernel for each virtual environment to use it in Jupyter.
#
# ```
# $ source dviz-env/bin/activate
# $ pip install ipykernel
# $ python -m ipykernel install --user --name=dviz
# ```
#
# ### Jupyter
#
# Once you have setup your local environment, you can run
#
# ```
# $ jupyter lab
# ```
#
# or use Jupyter notebook.
#
# ```
# jupyter notebook
# ```
#
# Jupyter lab is the 'next generation' notebook system with many powerful features. Some packages that we use work more nicely with Jupyter lab (for some lab assignments you may need to use jupyter notebook instead of the lab).
#
# Jupyter also has a desktop app: https://github.com/jupyterlab/jupyterlab-desktop
#
# ### nteract
#
# Another convenient way to use Jupyter is using the [`nteract` app](https://nteract.io). This is essentially a desktop Jupyter app. Instead of running Jupyter server and using a web browser, you can simply open a notebook file with `nteract` app and you'll be able to run the code as if you're using the Jupyter on the web. If you use Atom editor, you can make it interactive by using https://nteract.io/atom.
#
# ### VS code
#
# [Visual Studio code](https://code.visualstudio.com/) is a powerful editor and it supports notebooks and interactivity for Python. If you open a Jupyter notebook file, it works seamlessly within VS code. With the [Remote - SSH plugin](https://marketplace.visualstudio.com/items?itemName=ms-vscode-remote.remote-ssh), you can maintain almost identical experience using a computing server.
#
#
# ## Cloud setup
#
# There are many cloud-based Jupyter notebook services. The best option is probably the Google Colaboratory. It allows installation of packages and you can even use GPU/TPUs!
#
# ### Google colaboratory
#
# [Google Colaboratory](https://colab.research.google.com/) is Google's collaborative Jupyter notebook service. This is the recommended cloud option. Most packages that we use are already installed and you can install additioanl packages by running
#
# ```
# !pip install packagename
# ```
#
# in the computing cell.
#
#
# ### Other options
#
# - Azure notebooks: Microsoft also has a cloud notebook service called [Azure notebooks](https://notebooks.azure.com/). This service also allows installing new packages through `!pip install ...`.
# - CoCalc (https://cocalc.com/) is a service by [SageMath](http://www.sagemath.org/). You can use it freely but the free version is slow and can be turned off without warning. Most of the packages that we use are pre-installed. We may be able to provide a subscription through the school.
# - Kaggle Kernels: The famous machine learning / data science competition service Kaggle offers cloud-based notebooks called [Kaggle kernels](https://www.kaggle.com/kernels). Because you can directly use all the Kaggle datasets, it is an excellent option to do your project if you use one of the Kaggle datasets. It allows uploading your own dataset and install some packages, but not all packages are supported.
#
#
#
# # Lab assignment
#
# 1. Set up your local Python environment following the instructions. You should be using a virtual environment on your local machine.
# 1. Install Jupyter notebook and Jupyter lab.
# 1. Launch jupyter notebook (lab)
# 1. Create a new notebook and play with it. Print "Hello world!".
#
# If you want to use a cloud environment,
#
# 1. Try out the cloud environments listed above. (Google colaboratory is recommended)
# 1. Try installing/importing the following packages.
# 1. Create a cell that prints "Hello world!".
# 1. Submit the notebook.
#
#
# Finally, these are the packages that we plan to use. So check out their homepages and figure out what they are about.
#
# - Jupyter Notebook and Lab: https://jupyter.org/
# - numpy: http://www.numpy.org/
# - scipy: http://www.scipy.org/
# - matplotlib: http://matplotlib.org/
# - seaborn: http://seaborn.pydata.org/
# - pandas: http://pandas.pydata.org/
# - scikit-learn: http://scikit-learn.org/stable/
# - altair: https://github.com/altair-viz/altair
# - vega_datasets: https://github.com/altair-viz/vega_datasets
# - bokeh: http://bokeh.pydata.org/en/latest/
# - datashader: http://datashader.org/
# - holoviews: http://holoviews.org/
# - wordcloud: https://github.com/amueller/word_cloud
# - spacy: https://spacy.io/
#
# Install them using your package manager (conda or pip).
#
# Once you have installed the Jupyter locally or succeeded with a cloud environment, run the following import cell to make sure that every package is installed successfully. Submit the notebook on the canvas.

# %%
# !pip install numpy scipy matplotlib seaborn pandas altair vega_datasets sklearn bokeh datashader holoviews wordcloud spacy
# Out:
# Requirement already satisfied: numpy in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (1.23.5)
# Requirement already satisfied: scipy in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (1.10.0)
# Requirement already satisfied: matplotlib in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (3.7.0)
# Requirement already satisfied: seaborn in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: pandas in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: altair in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (5.0.1)
# Requirement already satisfied: vega_datasets in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: sklearn in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (0.0.post5)
# Requirement already satisfied: bokeh in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (2.4.3)
# Requirement already satisfied: datashader in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (0.14.4)
# Requirement already satisfied: holoviews in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (1.15.4)
# Requirement already satisfied: wordcloud in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (1.9.2)
# Requirement already satisfied: spacy in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (3.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: jinja2 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from altair) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from altair) (4.17.3)
# Requirement already satisfied: toolz in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from altair) (0.12.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from altair) (4.4.0)
# Requirement already satisfied: PyYAML>=3.10 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from bokeh) (6.0)
# Requirement already satisfied: tornado>=5.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from bokeh) (6.1)
# Requirement already satisfied: colorcet in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from datashader) (3.0.1)
# Requirement already satisfied: dask in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from datashader) (2022.7.0)
# Requirement already satisfied: datashape in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from datashader) (0.5.4)
# Requirement already satisfied: numba>=0.51 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from datashader) (0.56.4)
# Requirement already satisfied: param in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from datashader) (1.12.3)
# Requirement already satisfied: pyct in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from datashader) (0.5.0)
# Requirement already satisfied: requests in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from datashader) (2.28.1)
# Requirement already satisfied: xarray in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from datashader) (2022.11.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from holoviews) (2.0.2)
# Requirement already satisfied: panel>=0.13.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from holoviews) (0.14.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (4.64.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (1.10.8)
# Requirement already satisfied: setuptools in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (65.6.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from jinja2->altair) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from numba>=0.51->datashader) (0.39.1)
# Requirement already satisfied: markdown in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from panel>=0.13.1->holoviews) (3.4.1)
# Requirement already satisfied: bleach in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from panel>=0.13.1->holoviews) (4.1.0)
# Requirement already satisfied: six>=1.5 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from requests->datashader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from requests->datashader) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from requests->datashader) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from requests->datashader) (2022.12.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpickle>=1.1.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from dask->datashader) (2.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from dask->datashader) (2022.11.0)
# Requirement already satisfied: partd>=0.3.10 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from dask->datashader) (1.2.0)
# Requirement already satisfied: multipledispatch>=0.4.7 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from datashape->datashader) (0.6.0)
# Requirement already satisfied: locket in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from partd>=0.3.10->dask->datashader) (1.0.0)
# Requirement already satisfied: webencodings in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from bleach->panel>=0.13.1->holoviews) (0.5.1)

# %%
import numpy
import scipy
import matplotlib
import seaborn
import pandas
import altair
import vega_datasets
import sklearn
import bokeh
import datashader
import holoviews
import wordcloud
import spacy

# %%
pip install Cython
# Out:
# Requirement already satisfied: Cython in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (0.29.35)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pystan==2.19.1.1
# Out:
# Collecting pystan==2.19.1.1
#   Using cached pystan-2.19.1.1.tar.gz (16.2 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from pystan==2.19.1.1) (0.29.35)
# Requirement already satisfied: numpy>=1.7 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from pystan==2.19.1.1) (1.23.5)
# Building wheels for collected packages: pystan
#   Building wheel for pystan (setup.py) ... -^C
# anceled
# ERROR: Operation cancelled by user

# %%
# !pip install fbprophet
# Out:
# Collecting fbprophet
#   Using cached fbprophet-0.7.1.tar.gz (64 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython>=0.22 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fbprophet) (0.29.35)
# Requirement already satisfied: cmdstanpy==0.9.5 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fbprophet) (0.9.5)
# Requirement already satisfied: pystan>=2.14 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fbprophet) (3.7.0)
# Requirement already satisfied: numpy>=1.15.4 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fbprophet) (1.23.5)
# Requirement already satisfied: pandas>=1.0.4 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fbprophet) (1.5.3)
# Requirement already satisfied: matplotlib>=2.0.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fbprophet) (3.7.0)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fbprophet) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fbprophet) (2.4.0)
# Requirement already satisfied: holidays>=0.10.2 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fbprophet) (0.26)
# Requirement already satisfied: setuptools-git>=1.2 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fbprophet) (1.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fbprophet) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from fbprophet) (4.64.1)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from convertdate>=2.1.2->fbprophet) (0.5.12)
# Requirement already satisfied: ephem>=3.7.5.3 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from LunarCalendar>=0.0.9->fbprophet) (4.1.4)
# Requirement already satisfied: pytz in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from LunarCalendar>=0.0.9->fbprophet) (2022.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from matplotlib>=2.0.0->fbprophet) (3.0.9)
# Requirement already satisfied: aiohttp<4.0,>=3.6 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from pystan>=2.14->fbprophet) (3.8.4)
# Requirement already satisfied: clikit<0.7,>=0.6 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from pystan>=2.14->fbprophet) (0.6.2)
# Requirement already satisfied: httpstan<4.11,>=4.10 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from pystan>=2.14->fbprophet) (4.10.0)
# Requirement already satisfied: pysimdjson<6.0.0,>=5.0.2 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from pystan>=2.14->fbprophet) (5.0.2)
# Requirement already satisfied: setuptools in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from pystan>=2.14->fbprophet) (65.6.3)
# Requirement already satisfied: six>=1.5 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.0->fbprophet) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (22.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (1.3.1)
# Requirement already satisfied: crashtest<0.4.0,>=0.3.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet) (0.3.1)
# Requirement already satisfied: pastel<0.3.0,>=0.2.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet) (0.2.1)
# Requirement already satisfied: pylev<2.0,>=1.3 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet) (1.4.0)
# Requirement already satisfied: appdirs<2.0,>=1.4 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet) (1.4.4)
# Requirement already satisfied: marshmallow<4.0,>=3.10 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet) (3.19.0)
# Requirement already satisfied: webargs<9.0,>=8.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet) (8.2.0)
# Requirement already satisfied: idna>=2.0 in /Users/macbookpro/anaconda3/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (3.4)
# Building wheels for collected packages: fbprophet
#   Building wheel for fbprophet (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [56 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib
#       creating build/lib/fbprophet
#       creating build/lib/fbprophet/stan_model
#       NumExpr defaulting to 8 threads.
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/mj/2jnh99297wzd4z8ycdkw04y80000gn/T/pip-install-ulovdxfm/fbprophet_8895391430cf4df2a3446ad2fd9f9b4e/setup.py", line 122, in <module>
#           setup(
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/setuptools/__init__.py", line 87, in setup
#           return distutils.core.setup(**attrs)
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 325, in run
#           self.run_command("build")
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/command/build.py", line 132, in run
#           self.run_command(cmd_name)
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/setuptools/dist.py", line 1208, in run_command
#           super().run_command(command)
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/private/var/folders/mj/2jnh99297wzd4z8ycdkw04y80000gn/T/pip-install-ulovdxfm/fbprophet_8895391430cf4df2a3446ad2fd9f9b4e/setup.py", line 48, in run
#           build_models(target_dir)
#         File "/private/var/folders/mj/2jnh99297wzd4z8ycdkw04y80000gn/T/pip-install-ulovdxfm/fbprophet_8895391430cf4df2a3446ad2fd9f9b4e/setup.py", line 36, in build_models
#           from fbprophet.models import StanBackendEnum
#         File "/private/var/folders/mj/2jnh99297wzd4z8ycdkw04y80000gn/T/pip-install-ulovdxfm/fbprophet_8895391430cf4df2a3446ad2fd9f9b4e/fbprophet/__init__.py", line 8, in <module>
#           from fbprophet.forecaster import Prophet
#         File "/private/var/folders/mj/2jnh99297wzd4z8ycdkw04y80000gn/T/pip-install-ulovdxfm/fbprophet_8895391430cf4df2a3446ad2fd9f9b4e/fbprophet/forecaster.py", line 17, in <module>
#           from fbprophet.make_holidays import get_holiday_names, make_holidays_df
#         File "/private/var/folders/mj/2jnh99297wzd4z8ycdkw04y80000gn/T/pip-install-ulovdxfm/fbprophet_8895391430cf4df2a3446ad2fd9f9b4e/fbprophet/make_holidays.py", line 14, in <module>
#           import fbprophet.hdays as hdays_part2
#         File "/private/var/folders/mj/2jnh99297wzd4z8ycdkw04y80000gn/T/pip-install-ulovdxfm/fbprophet_8895391430cf4df2a3446ad2fd9f9b4e/fbprophet/hdays.py", line 924, in <module>
#           class TU(Turkey):
#         File "/Users/macbookpro/anaconda3/lib/python3.10/site-packages/holidays/registry.py", line 177, in __init__
#           raise TypeError(
#       TypeError: This is a python-holidays entity loader class. For entity inheritance purposes please import a class you want to derive from directly: e.g., `from holidays.countries import Entity` or `from holidays.financial import Entity`.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for fbprophet
#   Running setup.py clean for fbprophet
# Failed to build fbprophet
# ERROR: Could not build wheels for fbprophet, which is required to install pyproject.toml-based projects
